# %% [markdown]
# <a href="https://colab.research.google.com/github/barbarajamilly285-stack/engenharia-de-dados/blob/main/modulo-01/aula_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Olá mundo!
#
# vamos conhecher mais como funciona o ambiente interativo de um notebook. Paraisso vamos executar nosso primeiro comando em python: print().

# %%
print('Olá mundo!')
# Out:
# Olá mundo!

# %%
print(10)
# Out:
# 10

# %%
print('Bárbara',23)
# Out:
# Bárbara 23

# %% [markdown]
# Prática:

# %%
print('Escola de Dados da Alura!')
# Out:
# Escola de Dados da Alura!

# %%
print('Nome:Bárbara')
print('Sobrenome:Costa')
# Out:
# Nome:Bárbara
# Sobrenome:Costa

# %%
print('B')
print('A')
print('R')
print('B')
print('A')
print('R')
print('A')
# Out:
# B
# A
# R
# B
# A
# R
# A

# %%
print(14, 'Julho', 2003)
# Out:
# 14 Julho 2003

# %%
print('Ano atual:', 2026)
# Out:
# Ano atual: 2026

# %%
# Esse é um comentário de uma linha
print(10) #Podemos colocar outro comentário em uma linha após um código
# Out:
# 10

# %%
'''
Esse é um comentário
de várias linhas.
'''
# Out:
# '\nEsse é um comentário \nde várias linhas.\n'

# %% [markdown]
# Para construir cabeçalhos podemos usar o símbolo # antes do texto. Quanto mais símbolos # usarmos, menor será o nível do cabeçalho. Exemplo:
#
# # Cabeçalho de nível 1
# ## Cabeçalho de nível 2
# ### Cabeçalho de nível 3

# %% [markdown]
# Negrito e itálico
#
# Para construir texto em negrito, podemos usar ** antes e depois do texto, como o exemplo:
#
# **Texto em negrito**
#
# Já para construir texto em itálico, usamos * antes e depois do texto. Por exemplo:
#
# *Texto em itálico*
#
#
# É possivel unir os dois modos de escrita agrupando as duas estruturas com ** e *. Exemplo:
#
# ***Texto em negrito e itálico***

# %% [markdown]
# Listas
#
# Para construir listas não numeradas (em bullets), colocamos * e depois um espaço (*) antes do item, como no exemplo:
#
# * Item 1
# * Item 2
# * Item 3
#
# Já para construir listas numeradas, podemos usar um número seguidos de um ponto e um espaço (1.) antes do item, como no exemplo:
#
#
# 1. Item 1
# 2. Item 2
# 3. item 3

# %% [markdown]
# Links
#
# Para construir links, usamos a seguinte sintaxe: [texto do link] (link). A seguir temos um exemplo com o link da plataforma da alura:
#
# [Site da Alura] (https://www.alura.com.br/)

# %% [markdown]
# Manipulando Dados
#
# Vamos aprender sobre as variáveis no python, como elas são declaradas e utilizadas além de conhecer outros comandos dentro do Python. :D

# %% [markdown]
# Variáveis
#
# Em Data Science nós trabalhamos com dados e informação, então é essemcial saber trabalhar com variáveis.
#
# Criamos uma variável no python através da atribuiçãi de um valor a ela.
# Pra fazer isso, colocamos o nome da variável um sinal de igual (=) e o valor que queremos atribuir

# %%
idade = 5

# %%
print(idade)
# Out:
# 5

# %%
idade = 10
print(idade)
# Out:
# 10

# %%
idade = 15
idade
# Out:
# 15

# %%
nome = 'Gabriel'
nome
# Out:
# 'Gabriel'

# %% [markdown]
# Nomes que não podemos definir para variáveis:
#
#   Nomes que começam com números
#      Exemplos: 10_notas, 2_nomes_casa, etc.
#
# Palavras separada por espaço
#      Exemplos: Nome escola, notas estudantes, etc.
#
# Nomes de funções do Python
#      Exemplos: print, type, etc.

# %% [markdown]
# letras maiúsculas e minúsculas vão gerar diferentes variáveis. A variável idade é diferente de Idade que por sua vez também é diferente de IDADE:

# %%
idade = 1
Idade = 2
IDADE = 3
_idade = 4
_idade_ = 5
print(idade, Idade, IDADE, _idade, _idade_)
# Out:
# 1 2 3 4 5

# %% [markdown]
# | CLASSE | DESCRIÇÃO | EXEMPLO |
# | :--- | :--- | :--- |
# | `int` | Armazena números inteiros | `3`, `100` ou `-5` |
# | `float` | Armazena números com ponto flutuante, ou seja, números que possuem uma parte fracionária ou reais | `3.14`, `100.0` ou `-0.5` |
# | `str` | Armazena strings, ou seja, um texto ou sequências de caracteres. As strings são geralmente usadas para armazenar texto e são delimitadas por aspas simples ou duplas | `"Olá!"`, `'Alura'` ou `"1234"` |
# | `bool` | Armazena valores lógicos: verdadeiro ou falso | `True` ou `False` |

# %% [markdown]
# Tipos de variáveis
#
# Cada variável contém uma classe especifica quanto ao tipo de objeto que elaa está se referenciando. Essas classes vão ser diferentes a partir do tipo de dado que nós atribuimos a uma variável.
#
# Para saber a classe de cada elemento usams a função type().

# %%
i = 5
type(i)
# Out:
# int

# %%
f = 9.8
type(f)
# Out:
# float

# %%
s = 'Barbara'
type(s)
# Out:
# str

# %%
b = True
type(b)
# Out:
# bool

# %%
nome_aluno = 'Fabricio Daniel'
idade_aluno = 15
media_aluno = 8.45
situação_aprovado = True
print(nome_aluno, idade_aluno, media_aluno, situação_aprovado)
# Out:
# Fabricio Daniel 15 8.45 True

# %% [markdown]
# Variáveis numéricas
#
# Entre os tipos de dados numéricos vamos nos focar no tipo inteiro e float.
#
# Temos uma tabela de informção de empregos quanto ao cargo, quantidade de pessoas empregadas e o salário correspondente:

# %%
q_seguranca = 5
s_seguranca = 3000

q_docente = 16
s_docente = 6000

q_diretoria = 1
s_diretoria = 12500

# %%
total_empregados = q_seguranca + q_docente + q_diretoria
total_empregados
# Out:
# 22

# %%
diferenca_salario = s_diretoria - s_seguranca
diferenca_salario
# Out:
# 9500

# %%
media = (q_seguranca*s_seguranca + q_docente*s_docente + q_diretoria*s_diretoria) / (total_empregados)
media
# Out:
# 5613.636363636364

# %% [markdown]
# Exponenciação (**)
# Conseguimos elevar o número à uma potência definida através do operador **. Para ter esse resultado, definimos um valor à esquerda do operador e a potência desejada do número à direita. Por exemplo: sabemos que 2 elevado à 3 é igual a 8 (2*2*2 = 8). Para reproduzir esse cálculo colocamos:

# %%
2**3
# Out:
# 8

# %%
# O mesmo exemplo pode ser feito com variáveis.

operador = 2
potencia = 3
operador ** potencia
# Out:
# 8

# %% [markdown]
# Módulo (%)
# O operador de módulo pode retornar o resto da divisão inteira entre dois números. Lembrando que o resto de uma divisão é o número que sobra quando uma divisão não é exata.
#
# Para calcularmos o módulo de uma divisão, colocamos o dividendo à esquerda no operador % e o divisor à direita. Para encontramos o resto da divisão de 7 por 3, por exemplo, podemos executar os seguintes códigos:

# %%
7%3
# Out:
# 1

# %%
# Ou com variáveis.

dividendo = 7
divisor = 3
dividendo % divisor
# Out:
# 1

# %% [markdown]
# Divisão inteira (//)
# Essa operação retorna o resultado da divisão inteira entre dois números, ou seja, retorna apenas a parte inteira de uma divisão. Por exemplo, sabemos que a divisão exata de 7 por 3 (7/3) resulta no valor 2.333333…. Caso essa fosse uma divisão inteira, o resultado dela seria apenas 2. Sua sintaxe consiste em colocar o valor do numerador, o operador // e depois o denominador, como consta a seguir:

# %%
7 // 3
# Out:
# 2

# %%
# O mesmo exemplo pode ser feito com variáveis.

numerador = 7
denominador = 3
numerador // denominador
# Out:
# 2

# %% [markdown]
# # Strings

# %% [markdown]
# Strings são caracterizada por ter um conjunto de caracteres formando um texto.
#
# Strigs podem ser criadas ao atribuirmos a uma variável um dado que esteja entre aspas simples (') ou aspas duplas (")

# %%
s1 = 'Alura'
s2 = "Alura"
print(type(s1), type(s2))
# Out:
# <class 'str'> <class 'str'>

# %% [markdown]
# As variáveis textuais contém vários métodos que nos ajudam a formatar strings. Métódos podem ser executados ao definirmos um objeto seguindo a seguinte estrutura:
#
# ```
# objeto.metodo()
# ```
#
# Existem métodos que não necessitam dos `()`, é preciso verificar a documentação de cada caso.

# %% [markdown]
# ---
# **Situação**
#
# Recebemos uma variávelcom o nome de uma professora da escola para inserimos no cadastro. No entanto, precisamos tratar esse texto antes de inserimos no sistema.

# %%
texto = ' Geovana Alessandra dias Sanyos '

# %% [markdown]
# O objetivo final é que o nome esteja da seguinte forma:
#
# ```
# 'GEOVANA ALESSANDRA DIAS SANTOS'
# ```

# %% [markdown]
# ### [`str.upper()` ](https://docs.python.org/3/library/stdtypes.html#str.upper)
# Converte uma string para maiúsculas

# %%
texto.upper()
# Out:
# ' GEOVANA ALESSANDRA DIAS SANYOS '

# %% [markdown]
# ### [`str.lower()`](https://docs.python.org/3/library/stdtypes.html#str.lower)
# Método converte uma string para minúsculas.

# %%
texto.lower()
# Out:
# ' geovana alessandra dias sanyos '

# %% [markdown]
# ### [`str.strip()`](https://docs.python.org/3/library/stdtypes.html#str.strip)
# Método remove os espaços em branco do início e do fim de uma string.

# %%
texto.strip()
# Out:
# 'Geovana Alessandra dias Sanyos'

# %% [markdown]
# ### [`str.replace(antigo, novo)`](https://docs.python.org/3/library/stdtypes.html#str.replace)
#
# Método substitui todas as ocorrências do texto "antigo" na string por "novo"

# %%
texto.replace('y', 't')
# Out:
# ' Geovana Alessandra dias Santos '

# %% [markdown]
# ### Observações
#
# 1. Os métodos retornam uma **tranformação**, não a executam no texto!
#
# 2. Além disso, podemos acumular a execução de métodos.

# %%
texto
# Out:
# ' Geovana Alessandra dias Sanyos '

# %% [markdown]
# Para que seja executada a transformação nós podemos atribuir ás saídas das transformações á variável

# %%
texto = texto.strip().replace('y','t').upper()
texto
# Out:
# 'GEOVANA ALESSANDRA DIAS SANTOS'

# %% [markdown]
# Podemos imprimir um elemento da tabela Unicode em nosso notebook através da função chr, que é uma função que retorna uma string com o caractere especificado. Sua sintaxe de uso é dada da seguinte forma: chr(numero_do_caractere). Como exemplo, vamos imprimir o caractere “@” com chr(). Segundo a tabela, sabemos que o @ corresponde ao número 64, então reproduzimos:

# %%
chr(64)
# Out:
# '@'

# %% [markdown]
# Várias outras combinações de números podem ser testadas e observadas nas saídas. Sinta-se livre para testar várias combinações e até mesmo criar frases!

# %% [markdown]
# Também é possivel concatenar com operador +. Sabendo disso, se nós unimos vários caracteres, conseguimos obter uma palavra. Como exemplo, vamos construir a palavra Olá ('o' + 'l' + 'á'):

# %%
chr(79) + chr(108) + chr(225)
# Out:
# 'Olá'

# %% [markdown]
# Coletando dados
# Em algumas aplicações precisamos coletar valores da pessoa usuária do nosso projeto. Em python conseguimos coletar dados de usuário através do comando input().
#
# Para fazer essa coleta podemos atribuir essa função à uma variável.

# %%
nome = input('Escreva seu nome: ')
# Out:
# Escreva seu nome: Bárbara

# %%
nome
# Out:
# 'Bárbara'

# %% [markdown]
# O retorno desse comando sempre será uma *string*. Isso quer dizer que mesmo que façamos uma coleta de algo que deva ser numérico, ele será uma string.
#
# Então, será preciso **converter o resultado caso não seja desejável obter uma string**.

# %% [markdown]
# Existem funções para conversão de valores:
#
# - Inteiros: [`int(dado_para_conversao)`](https://docs.python.org/3/library/functions.html#int)
# - Float: [`float(dado_para_conversao)`](https://docs.python.org/3/library/functions.html#float)
# - String: [`str(dado_para_conversao)`](https://docs.python.org/3/library/functions.html#func-str)
# - Booleano: [`bool(dado_para_conversao)`](https://docs.python.org/3/library/functions.html#bool)

# %%
ano_entrada = input('Escreva o ano de ingresso do(a) estudante: ')
# Out:
# Escreva o ano de ingresso do(a) estudante: 2024

# %%
type(ano_entrada)
# Out:
# str

# %%
ano_entrada = int(input('Escreva o ano de ingresso do(a) estudante: '))
# Out:
# Escreva o ano de ingresso do(a) estudante: 2024

# %%
type(ano_entrada)
# Out:
# int

# %% [markdown]
# Buscaremos apresentar melhor agora o resultado que obtivemos da transformação. Nós conseguimos formatar e apresentar o nosso resultado misturando strings com valores não textuais.
#
# Para fazer isso usamos a estrutura de formatação `f` com strings.

# %%
nota_entrada = float(input('Digite a nota do teste de ingresso: '))
print(f'Ano de entrada {ano_entrada} - nota de teste de ingresso {nota_entrada}')
# Out:
# Digite a nota do teste de ingresso: 8.5
# Ano de entrada 2024 - nota de teste de ingresso 8.5

# %% [markdown]
# Conseguimos visualizar o resultado de variáveis dentro de strings, bem como imprimir o texto final em um print. Durante a aula, aprndemos a utilizar a formatação ***f-string*** (ou formatção de string), na qual colocamos um `f` antes da criação da string e as variáveis entre chaves `{}`. Exemplo:

# %%
nome = "Ana Maria"
idade = 18
print(f"O nome da aluna é {nome} e sua idade é {idade} anos.")
# Out:
# O nome da aluna é Ana Maria e sua idade é 18 anos.

# %% [markdown]
# Mas existem outras formatações, como o uso do operador de formatação de string ou da função `.format()`.

# %% [markdown]
# ## Operador de formatação

# %% [markdown]
# Esse operador de formatação permite a inserção de variáveis em pontos específicos na string com o operador `%`. Esse operador funciona como um marcador, informando onde o volar da variável vai ser exposto na string.

# %% [markdown]
# O `%` precisa ser acompanhado de uma palavra-chave para cada tipo de variável que se deseja adicionar.
# Seguindo a tabela abaixo:

# %% [markdown]
# | Tipo de variável | Palavra-chave |
# | :--- | :--- |
# |string            |      `%s`
# |inteiro           |      `%d`
# |float             |      `%f`
# |caractere         |      `%c`

# %% [markdown]
# Desse modo, para inserimos uma variável, podemos adicionar o operador pela string no ponto desejado. Após o fim da string, adicionamos novamente o `%`, mas agora especificando a variável entre parênteses. Podemos observar essa estrutura no exemplo abaixo:

# %%
nome_aluno = 'Fabricio Daniel'
print('Nome do aluno: %s' %(nome_aluno))
# Out:
# Nome do aluno: Fabricio Daniel

# %% [markdown]
# Caso tenha mais de uma variável, devemos ordená-las conforme seu surgimento no texto e separá-la por vírgula

# %%
nome_aluno = 'Fabricio Daniel'
idade_aluno = 17
media_aluno = 8.5
print('Nome do aluno é %s, ele tem %d anos e sua media é %f.'%(nome_aluno, idade_aluno, media_aluno))
# Out:
# Nome do aluno é Fabricio Daniel, ele tem 17 anos e sua media é 8.500000.

# %% [markdown]
# Quando trabalhamos com pontos flutuantes (`float`), podemos determinar a quantidade de casas decimais após a vírgula usando a sintaxe `%.xf`, na qual `x` é o número de casas desejadas. Utilizando as mesmas variáveis do exemplo anterior, o código com `%.xf` fica da seguinte maneira:

# %%
print('Nome do aluno é %s, ele tem %d anos e sua media é %.1f.'%(nome_aluno, idade_aluno, media_aluno))
# Out:
# Nome do aluno é Fabricio Daniel, ele tem 17 anos e sua media é 8.5.

# %% [markdown]
# Note que, com o `format`, não temos o problema das casas decimais do ponto flutuante. Esse problema também não é presente no formato f-string.

# %% [markdown]
# Em resumo, cada uma dessas formas tem suas vantagens e desvantagens. Indico utilizar a forma f-string, pois é mais legível e fácil de usar. Mesmo assim, cada pessoa desenvolvedora pode escolher a forma que achar mais apropriada.

# %% [markdown]
#  ### **Caracteres especias**

# %% [markdown]
# Além da formatação de inserção de variáveis dentro de uma string, também existem os **caracteres especiais**. Eles são usados para representar ações especiais ou caracteres que não podem ser digitados diretamente, como o Enter e a tabulação. Vamos conhecer alguns deles? Busque reproduzir todos os exemplos e visualizar o resultado final.

# %% [markdown]
# - `\n` é o caractere de nova linha e é usado para pular uma linha no texto (função do enter). Exemplo:

# %%
print("estudar é um esforço constante, \nÉ como cultivar uma planta, \nPrecisamos de dedicação e paciência, \nPara ver o fruto amadurecer.")
# Out:
# estudar é um esforço constante,
# É como cultivar uma planta,
# Precisamos de dedicação e paciência,
# Para ver o fruto amadurecer.

# %% [markdown]
# - `\t` é o caractere de tabulação usado para adicionar um espaço de tabulação no texto. Exemplo:

# %%
print('Quantidade\tQualidade\n5 amostras\tAlta\n3 amostras\tBaixa')
# Out:
# Quantidade	Qualidade
# 5 amostras	Alta
# 3 amostras	Baixa

# %% [markdown]
# - `\\` é usado para imprimir uma única barra invertida. Caso não seja usada a dupla barra invertida, o código poderá resultar em erro ou em um resultado inesperado, pois o Python considera a `\` um chamado para um caractere especial. Usamos esta sintaxe para garantir que não ocorram erros. Exemplo:

# %%
print("Caminho do arquivo: C:\\arquivos\\documento.csv")
# Out:
# Caminho do arquivo: C:\arquivos\documento.csv

# %% [markdown]
# - `\"` é usado para imprimir aspas duplas quando estamos trabalhando com uma string criada a partir de aspas duplas `"`. Porém, isso não é necessário caso seja uma string criada por aspas simples `'`. Como exemplo, temos:

# %%
print("Ouvi uma vez \"Os frutos do conhecimento são os mais doces e dourados de todos. \"")
# Out:
# Ouvi uma vez "Os frutos do conhecimento são os mais doces e dourados de todos. "

# %% [markdown]
# - `\'` é usado para imprimir aspas simples quando estamos trabalhando com uma string criada a partir de aspas simples `'`. Caso seja uma string criada por aspas duplas `"`, isso não é necessário. Exemplo:

# %%
print('Minha professora uma vez disse \'Estudar é a chave do sucesso.\'')
# Out:
# Minha professora uma vez disse 'Estudar é a chave do sucesso.'

# %% [markdown]
# # Desafio: hora da Prática

# %% [markdown]
# Vamos praticar o uso de vários tipos de variáveis e da função `input` a partir de algumas atividades. Solucione os problemas propostos em código.

# %% [markdown]
# ## **Coleta e amostragem de dados**

# %% [markdown]
# 1. Crie um programa que solicite á pessoa usuária digitar seu nome, e imprima "Olá, [nome]!".

# %%
nome = input('Digite seu nome: ')
print(f'Olá, {nome}.')
# Out:
# Digite seu nome: Bárbara
# Olá, Bárbara.

# %% [markdown]
# 2. Crie um programa que solicite à pessoa usuária digitar seu nome e idade, e imprima "Olá, [nome], você tem [idade] anos.".

# %%
nome = input('Digite seu nome: ')
idade =int(input('Digite sua idade'))
print(f'Olá, {nome}, você tem {idade} anos.')
# Out:
# Digite seu nome: Bárbara
# Digite sua idade23
# Olá, Bárbara, você tem 23 anos.

# %% [markdown]
# 3. Crie um programa que solicite à pessoa usuária digitar seu nome, idade e altura em metros, e imprima "Olá, [nome], você tem [idade] anos e mede [altura] metros!".

# %%
nome = input('Digite seu nome: ')
idade = int(input('Digite sua idade: '))
altura = float(input('Digite a sua altura: ' ))
print(f'Olá, {nome}, você tem {idade} anos e mede {altura} metros!')
# Out:
# Digite seu nome: Bárbara
# Digite sua idade: 23
# Digite a sua altura: 1.66
# Olá, Bárbara, você tem 23 anos e mede 1.66 metros!

# %% [markdown]
# ## **Calculadora com operadores**

# %% [markdown]
# 1. Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a soma do dois valores.

# %%
a = int(input('Digite o primeiro valor: '))
b = int(input('Digite o segundo valor: ' ))
print(a+b)
# Out:
# Digite o primeiro valor: 20
# Digite o segundo valor: 36
# 56

# %% [markdown]
# 2. Crie um programa que solicite três valores numéricos à pessoa usuária e imprima a soma dos três valores.

# %%
a = int(input('Digite o primeiro valor: ' ))
b = int(input('Digite o segundo valor: '))
c = int(input('Digite o terceiro valor: ' ))
print(a+b+c)
# Out:
# Digite o primeiro valor: 7
# Digite o segundo valor: 12
# Digite o terceiro valor: 63
# 82

# %% [markdown]
# 3. Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a subtração do primeiro pelo o segundo valor.

# %%
a = int(input('Digite o primeiro valor: '))
b = int(input('Digite o segundo valor: '))
print(a-b)
# Out:
# Digite o primeiro valor: 17
# Digite o segundo valor: 6
# 11

# %% [markdown]
# 4. Crie um programa que solicite dois valores numéricos à pessoa usuária e imprima a multiplicação dos dois valores.

# %%
a = int(input('Digite primeiro valor: '))
b = int(input('Digite o segundo valor: '))
print(a*b)
# Out:
# Digite primeiro valor: 63
# Digite o segundo valor: 5
# 315

# %% [markdown]
# 5. Crie um programa que solicite dois valores numéricos, um numerador e um denominador, e realize a divisão entre os dois valores. Deixe claro que o valor do denominador não pode ser 0

# %%
numerador = int(input('Digite o numerador: '))
denominador = int(input('Digite o denominador (OBS: o valor não pode ser nulo): '))
print(numerador/denominador)
# Out:
# Digite o numerador: 6
# Digite o denominador (OBS: o valor não pode ser nulo): 2
# 3.0

# %% [markdown]
# 6. Crie um programa que solicite dois valores numéricos, um operador e uma potência, e realize a exponenciação entre esses dois valores.

# %%
operador = int(input('Digite o operador valor: '))
potencia = int(input('Digite a potencia valor: '))
print(operador**potencia)

# %% [markdown]
# 7. Crie um programa que solicite dois valores numéricos, um numerador e um denominador e realize a divisão inteira entre os dois valores. Deixe claro que o valor do denominador não pode ser 0.

# %%
numerador = int(input('Digite o numerador valor: '))
denominador = int(input('Digite o denominador valor (OBS: o valor não pode ser nulo): '))
print(numerador//denominador)
# Out:
# Digite o numerador valor: 10
# Digite o denominador valor (OBS: o valor não pode ser nulo): 4
# 2

# %% [markdown]
# 8. Crie um programa que solicite dois valores numéricos, um numerador e um denominador, e retorne o resto da divisão entre os dois valores. Deixe claro que o valor do denominador não pode ser 0.

# %%
numerador = int(input('Digite o numerador valor: '))
denominador = int(input('Digeti o denominador valor (OBS: o valor não pode ser nulo): '))
print(numerador%denominador)
# Out:
# Digite o numerador valor: 48
# Digeti o denominador valor (OBS: o valor não pode ser nulo): 6
# 0

# %% [markdown]
# 9. Crie um código que solicita 3 notas de um estudante e imprima a média das notas.

# %%
nota_1 = float(input('Digite a 1° nota: '))
nota_2 = float(input('Digite a 2° nota: '))
nota_3 = float(input('Digite a 3° nota: '))
print(f'Média {(nota_1+nota_2+nota_3)/3}.')
# Out:
# Digite a 1° nota: 8.5
# Digite a 2° nota: 9.0
# Digite a 3° nota: 7.6
# Média 8.366666666666667.

# %% [markdown]
# 10. Crie um código que calcule e imprima a média ponderada dos números 5, 12, 20 e 15 com pesos respectivamente iguais a 1, 2, 3 e 4

# %%
media_ponderada = (5*1 + 12*2 + 20*3 + 15*4) / (1+2+3+4)
print(f'Média {media_ponderada}.')
# Out:
# Média 14.9.

# %% [markdown]
# ## **Editando textos**

# %% [markdown]
# 1. Crie uma variável chamada `“frase”` e atribua a ela uma string de sua escolha. Em seguida, imprima a frase na tela.

# %%
frase = 'Olá Python!'
print(frase)
# Out:
# Olá Python!

# %% [markdown]
# 2. Crie um código que solicite uma frase e depois imprima a frase na tela.

# %%
frase = input('Digite uma frase: ')
print(frase)
# Out:
# Digite uma frase: Deus é maravilhoso!
# Deus é maravilhoso!

# %% [markdown]
# 3. Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase digitada mas com todas as letras maiúsculas.

# %%
frase = input('Digite uma frase: ')
print(frase.upper())
# Out:
# Digite uma frase: o amor é bondoso!
# O AMOR É BONDOSO!

# %% [markdown]
# 4. Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase digitada mas com todas as letras minúsculas.

# %%
frase = input('Digite uma frase: ')
print(frase.lower())
# Out:
# Digite uma frase: Deus é amor!
# deus é amor!

# %% [markdown]
# 5. Crie uma variável chamada `“frase”` e atribua a ela uma string de sua escolha. Em seguida, imprima a frase sem espaços em branco no início e no fim.

# %%
frase = ' Olá Python! '
print(frase.strip())
# Out:
# Olá Python!

# %% [markdown]
# 6. Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase sem espaços em branco no início e no fim.

# %%
frase = input('Digite uma frase: ')
print(frase.strip())
# Out:
# Digite uma frase: Olá Python!
# Olá Python!

# %% [markdown]
# 7. Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase sem espaços em branco no início e no fim e em letras minúsculas.

# %%
frase = input('Digite uma frase: ')
print(frase.strip().lower())
# Out:
# Digite uma frase: Olá Python!
# olá python!

# %% [markdown]
# 8. Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase com todas as vogais “e” trocadas pela letra `“f”`.

# %%
frase = input('Digite uma frase: ')
print(frase.lower().replace('e', 'f'))
# Out:
# Digite uma frase: Feliz aniversário!
# ffliz anivfrsário!

# %% [markdown]
# 9. Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase com todas as vogais “a” trocadas pela caractere `“@”`.

# %%
frase = input('Diite uma frase: ')
print(frase.lower().replace('a', chr(64)))
# Out:
# Diite uma frase: Barbara Costa
# b@rb@r@ cost@

# %% [markdown]
# 10. Crie um código que solicite uma frase à pessoa usuária e imprima a mesma frase com todas as consoantes “s” trocadas pelo caractere `“$”`.

# %%
frase = input('Digite uma frase: ')
print(frase.lower().replace('s', chr(36)))
# Out:
# Digite uma frase: Sucesso!
# $uce$$o!
